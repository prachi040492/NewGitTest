# %%
#Proprietary content. ©Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
x=np.arange(1,11)
y1=2*x
y2=3*x

# %%
y1=2*x

# %%
y2=3*x

# %%
#Line plot

# %%
fig=plt.figure(figsize=(4,4))

# %%
plt.plot(x,y1,color='g',linestyle=':',linewidth=2)
plt.plot(x,y2,color='r',linestyle='-.',linewidth=3)
plt.title("Line Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(True)
plt.show()

# %%
#bar-plot

# %%
student = {"Bob":87,"Matt":56,"Sam":27}

# %%
names = list(student.keys())
values = list(student.values())

# %%
plt.bar(names,values)
plt.title("Bar Plot")
plt.xlabel("Names")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %%
plt.barh(names,values,color='g')
plt.title("Bar Plot")
plt.xlabel("Names")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %%
#scatter-plot

# %%
x=np.arange(1,11)
y1=2*x
y2=3*x
plt.scatter(x,y2)
plt.title("Bar Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(True)
plt.show()

# %%
x=[8,1,6,3,8,1,5]
y1=[6,2,7,9,1,4,5]

y2=[6,2,7,9,1,4,5]

# %%
x=np.arange(1,11)
y1=2*x
y2=3*x

plt.subplot(1,2,1)
plt.plot(x,y1,color='g',linestyle=':',linewidth=2)

plt.subplot(1,2,2)
plt.plot(x,y2,color='r',linestyle=':',linewidth=2)

plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
a=[8,1,7,2,0,3,7,3,2]

plt.scatter(x,a,c="red",marker="*")
plt.show()

# %%
x=[10,20,30,40,50,60,70,80,90]
a=[8,1,7,2,0,3,7,3,2]
b=[7,2,5,6,9,1,4,5,3]

plt.subplot(1,2,1)
plt.scatter(x,a,marker="*",c="g",s=100)

plt.subplot(1,2,2)
plt.scatter(x,b,marker=".",c="r",s=200)
plt.show()

# %%
#histogram

# %%
data = [1,3,3,3,3,9,9,5,4,4,8,8,8,6,7]

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data,color="g",bins=4)
plt.show()

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
iris=pd.read_csv('iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(iris['Sepal.Length'],bins=30,color="r")
plt.show()

# %%
one = [1,2,3,4,5,6,7,8,9]
two = [1,2,3,4,5,4,3,2,1]
three = [6,7,8,9,8,7,6,5,4]

data =  list([one,two,three])

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.boxplot(iris['Sepal.Length'],by=iris['Species'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8c74c762f0fd> in <module>
# ----> 1 plt.boxplot(iris['Sepal.Length'],by=iris['Species'])
#
# TypeError: boxplot() got an unexpected keyword argument 'by'

# %%
plt.violinplot(data,showmedians=True)
plt.show()

# %%
#pie

# %%
fruit = ['Apple','Orange','Mango','Guava']
quantity = [67,34,100,29]

# %%
plt.pie(quantity,labels=fruit,radius=2)
plt.pie([1],colors=['w'],radius=1)
plt.show()
