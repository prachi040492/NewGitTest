# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.describe(include = 'all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width     species
# count     150.000000   150.000000    150.000000   150.000000         150
# unique           NaN          NaN           NaN          NaN           3
# top              NaN          NaN           NaN          NaN  versicolor
# freq             NaN          NaN           NaN          NaN          50
# mean        5.843333     3.057333      3.758000     1.199333         NaN
# std         0.828066     0.435866      1.765298     0.762238         NaN
# min         4.300000     2.000000      1.000000     0.100000         NaN
# 25%         5.100000     2.800000      1.600000     0.300000         NaN
# 50%         5.800000     3.000000      4.350000     1.300000         NaN
# 75%         6.400000     3.300000      5.100000     1.800000         NaN
# max         7.900000     4.400000      6.900000     2.500000         NaN

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
df.species.value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
df['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
df1 = df[['sepal_length', 'sepal_width', 'species']].head()

# %%
df1.head()
# Out:
#    sepal_length  sepal_width species
# 0           5.1          3.5  setosa
# 1           4.9          3.0  setosa
# 2           4.7          3.2  setosa
# 3           4.6          3.1  setosa
# 4           5.0          3.6  setosa

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[df['sepal_length']>6.4].shape
# Out:
# (35, 5)

# %%
df[df['sepal_length']>6.4].tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 141           6.9          3.1           5.1          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 147           6.5          3.0           5.2          2.0  virginica

# %%
df[df['sepal_length']>6.4]['species'].value_counts()
# Out:
# virginica     26
# versicolor     9
# Name: species, dtype: int64

# %%
df_titanic = sns.load_dataset('titanic')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df_titanic.shape
# Out:
# (891, 15)

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
df_titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df_titanic.describe(include = 'all').T
# Out:
#             count unique          top freq      mean       std   min     25%  \
# survived      891    NaN          NaN  NaN  0.383838  0.486592     0       0
# pclass        891    NaN          NaN  NaN   2.30864  0.836071     1       2
# sex           891      2         male  577       NaN       NaN   NaN     NaN
# age           714    NaN          NaN  NaN   29.6991   14.5265  0.42  20.125
# sibsp         891    NaN          NaN  NaN  0.523008   1.10274     0       0
# parch         891    NaN          NaN  NaN  0.381594  0.806057     0       0
# fare          891    NaN          NaN  NaN   32.2042   49.6934     0  7.9104
# embarked      889      3            S  644       NaN       NaN   NaN     NaN
# class         891      3        Third  491       NaN       NaN   NaN     NaN
# who           891      3          man  537       NaN       NaN   NaN     NaN
# adult_male    891      2         True  537       NaN       NaN   NaN     NaN
# ...

# %%
df_titanic[df_titanic['fare']>50].shape[0]
# Out:
# 160

# %%
round(pd.crosstab(df_titanic['sex'], df_titanic['alive'], margins = True, normalize = 'index')*100,2)
# Out:
# alive      no    yes
# sex
# female  25.80  74.20
# male    81.11  18.89
# All     61.62  38.38

# %%
pd.crosstab(df_titanic['sex'], df_titanic['alive'], margins = True, normalize = 'index')
# Out:
# alive         no       yes
# sex
# female  0.257962  0.742038
# male    0.811092  0.188908
# All     0.616162  0.383838

# %%
pd.crosstab(df_titanic['sex'], df_titanic['alive'], margins = True)
# Out:
# alive    no  yes  All
# sex
# female   81  233  314
# male    468  109  577
# All     549  342  891

# %% [markdown]
# # Case Study

# %%
df = pd.read_csv('ForbesAmericasTopColleges2019.csv')

# %%
df.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 645   646  New Mexico State University   Las Cruces    NM         Public
# 646   647     Indiana State University  Terre Haute    IN         Public
# 647   648    Emory &amp; Henry College        Emory    VA        Private
# 648   649                Wells College       Aurora    NY        Private
# 649   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 645                     13379               14432     8625.0
# 646                     13626               13763    13012.0
# 647                      1094                1226    19340.0
# 648                       488                 516    22828.0
# 649                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 645             9582.0              34720        96700.0             64.0
# ...

# %%
df.shape
# Out:
# (650, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      650 non-null    int64
#  1   Name                      650 non-null    object
#  2   City                      650 non-null    object
#  3   State                     650 non-null    object
#  4   Public/Private            650 non-null    object
#  5   Undergraduate Population  650 non-null    int64
#  6   Student Population        650 non-null    int64
#  7   Net Price                 648 non-null    float64
#  8   Average Grant Aid         646 non-null    float64
#  9   Total Annual Cost         650 non-null    int64
#  10  Alumni Salary             635 non-null    float64
#  11  Acceptance Rate           648 non-null    float64
#  12  SAT Lower                 551 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
df.describe(include = 'all').T
# Out:
#                          count unique  \
# Rank                       650    NaN
# Name                       650    650
# City                       650    469
# State                      650     51
# Public/Private             650      2
# Undergraduate Population   650    NaN
# Student Population         650    NaN
# Net Price                  648    NaN
# Average Grant Aid          646    NaN
# Total Annual Cost          650    NaN
# Alumni Salary              635    NaN
# Acceptance Rate            648    NaN
# SAT Lower                  551    NaN
# SAT Upper                  551    NaN
# ACT Lower                  553    NaN
# ACT Upper                  553    NaN
# Website                    645    645
#
#                                                                top freq  \
# Rank                                                           NaN  NaN
# Name                      California State University, Los Angeles    1
# ...

# %%
df.drop(['Website', 'SAT Lower', 'SAT Upper', 'ACT Lower', 'ACT Upper'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (650, 12)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (628, 12)

# %%
df.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 644   645            Morehouse College      Atlanta    GA        Private
# 645   646  New Mexico State University   Las Cruces    NM         Public
# 646   647     Indiana State University  Terre Haute    IN         Public
# 647   648    Emory &amp; Henry College        Emory    VA        Private
# 649   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 644                      2202                2219    34928.0
# 645                     13379               14432     8625.0
# 646                     13626               13763    13012.0
# 647                      1094                1226    19340.0
# 649                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 644            17318.0              48723        98700.0             74.0
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 623   645            Morehouse College      Atlanta    GA        Private
# 624   646  New Mexico State University   Las Cruces    NM         Public
# 625   647     Indiana State University  Terre Haute    IN         Public
# 626   648    Emory &amp; Henry College        Emory    VA        Private
# 627   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 623                      2202                2219    34928.0
# 624                     13379               14432     8625.0
# 625                     13626               13763    13012.0
# 626                      1094                1226    19340.0
# 627                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# 623            17318.0              48723        98700.0             74.0
# ...

# %%
df.shape
# Out:
# (628, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      628 non-null    int64
#  1   Name                      628 non-null    object
#  2   City                      628 non-null    object
#  3   State                     628 non-null    object
#  4   Public/Private            628 non-null    object
#  5   Undergraduate Population  628 non-null    int64
#  6   Student Population        628 non-null    int64
#  7   Net Price                 628 non-null    float64
#  8   Average Grant Aid         628 non-null    float64
#  9   Total Annual Cost         628 non-null    int64
#  10  Alumni Salary             628 non-null    float64
#  11  Acceptance Rate           628 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 59.0+ KB

# %%
df.isnull().sum()
# Out:
# Rank                        0
# Name                        0
# City                        0
# State                       0
# Public/Private              0
# Undergraduate Population    0
# Student Population          0
# Net Price                   0
# Average Grant Aid           0
# Total Annual Cost           0
# Alumni Salary               0
# Acceptance Rate             0
# dtype: int64

# %%
df.describe().T
# Out:
#                           count          mean           std      min  \
# Rank                      628.0    322.122611    185.360460      1.0
# Undergraduate Population  628.0  10235.472930  11228.048723    323.0
# Student Population        628.0  12312.912420  13246.660229    406.0
# Net Price                 628.0  22481.570064   8099.771637   1298.0
# Average Grant Aid         628.0  19971.522293  11214.740998   2975.0
# Total Annual Cost         628.0  50722.579618  12670.126944   8646.0
# Alumni Salary             628.0  98616.242038  14026.078146  70700.0
# Acceptance Rate           628.0     61.721338     21.795857      5.0
#
#                                25%      50%        75%       max
# Rank                        161.75    321.5     479.25     650.0
# Undergraduate Population   2062.75   4825.5   15867.00   65100.0
# Student Population         2294.50   6538.5   18357.25   75044.0
# Net Price                 16476.00  22065.0   27880.75   47270.0
# ...

# %%
df[['Name', 'Rank']].head()
# Out:
#                                     Name  Rank
# 0                     Harvard University     1
# 1                    Stanford University     2
# 2                        Yale University     3
# 3  Massachusetts Institute of Technology     4
# 4                   Princeton University     5

# %%
df[['Name', 'State', 'City']].head()
# Out:
#                                     Name State       City
# 0                     Harvard University    MA  Cambridge
# 1                    Stanford University    CA   Stanford
# 2                        Yale University    CT  New Haven
# 3  Massachusetts Institute of Technology    MA  Cambridge
# 4                   Princeton University    NJ  Princeton

# %%
df['State'].nunique()
# Out:
# 51

# %%
df['State'].unique()
# Out:
# array(['MA', 'CA', 'CT', 'NJ', 'PA', 'RI', 'NC', 'NH', 'NY', 'DC', 'IL',
#        'IN', 'MI', 'TX', 'MD', 'ME', 'TN', 'MO', 'VA', 'VT', 'MN', 'GA',
#        'WA', 'WI', 'FL', 'OH', 'IA', 'CO', 'UT', 'OR', 'LA', 'SC', 'DE',
#        'AL', 'AZ', 'OK', 'NE', 'KY', 'KS', 'AR', 'WY', 'NV', 'MS', 'ND',
#        'HI', 'MT', 'SD', 'NM', 'ID', 'WV', 'AK'], dtype=object)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'City', 'State', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate'],
#       dtype='object')

# %%
df['Public/Private'].value_counts()
# Out:
# Private    384
# Public     244
# Name: Public/Private, dtype: int64

# %%
df['State'].value_counts()
# Out:
# NY    64
# CA    56
# PA    39
# MA    31
# OH    29
# TX    25
# IL    25
# FL    20
# NC    19
# VA    18
# MN    18
# IN    18
# MI    16
# TN    14
# GA    14
# WI    13
# NJ    13
# IA    13
# KY    12
# WA    12
# MO    12
# MD    12
# CO    11
# OR    11
# CT     9
# SC     8
# LA     8
# AL     7
# RI     7
# OK     6
# NE     6
# MS     5
# ME     5
# DC     5
# VT     4
# AZ     4
# UT     4
# MT     4
# ID     4
# AR     4
# SD     4
# NM     3
# KS     3
# NH     3
# ND     2
# NV     2
# AK     2
# WV     1
# DE     1
# HI     1
# WY     1
# Name: State, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'City', 'State', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate'],
#       dtype='object')

# %%
df['Percentage_UG'] = round(df['Undergraduate Population']/df['Student Population']*100,2)

# %%
df.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df[['Name', 'Percentage_UG']].sort_values(by='Percentage_UG', ascending = False).head()
# Out:
#                                        Name  Percentage_UG
# 556  University of Texas, Rio Grande Valley          99.99
# 246            Saint John's University (MN)          99.94
# 552                      Oakland University          99.94
# 357                    Salisbury University          99.92
# 338                     St. Norbert College          99.86

# %%
df.sort_values(by= 'Average Grant Aid', ascending = False).Name.head()
# Out:
# 2         Yale University
# 1     Stanford University
# 0      Harvard University
# 26        Amherst College
# 13    Columbia University
# Name: Name, dtype: object

# %%
df[['Name', 'Average Grant Aid']].sort_values(by='Average Grant Aid', ascending = False).head()
# Out:
#                    Name  Average Grant Aid
# 2       Yale University            50897.0
# 1   Stanford University            50134.0
# 0    Harvard University            49870.0
# 26      Amherst College            49467.0
# 13  Columbia University            49185.0

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'City', 'State', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate', 'Percentage_UG'],
#       dtype='object')

# %%
round(df[df.State == 'CA']['Undergraduate Population'].mean(),2)
# Out:
# 13186.91

# %%
df.sort_values(by='Acceptance Rate', ascending = False).head()
# Out:
#      Rank                                Name         City State  \
# 588   606        University of Texas, El Paso      El Paso    TX
# 607   627  University of Southern Mississippi  Hattiesburg    MS
# 339   347               University of Wyoming      Laramie    WY
# 616   638             Wright State University       Dayton    OH
# 300   308              University of Kentucky    Lexington    KY
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 588         Public                     24386               25078     8135.0
# 607         Public                     13606               14478    13178.0
# 339         Public                     10874               12397    13070.0
# 616         Public                     14332               15957    16249.0
# 300         Public                     23718               29465    18527.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df[df['Name'].str.contains("Art")]
# Out:
#      Rank                               Name           City State  \
# 295   303  Maryland Institute College of Art      Baltimore    MD
# 393   402   California Institute of the Arts  Santa Clarita    CA
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 295        Private                      2041                2128    38763.0
# 393        Private                       991                1498    46101.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 295            18939.0              62850        84500.0             62.0
# 393            15401.0              68993        91000.0             24.0
#
#      Percentage_UG
# 295          95.91
# 393          66.15

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df_new.shape
# Out:
# (628, 13)

# %%
df_new['Alumni Sal Level'] = pd.cut(df_new['Alumni Salary'], 3, labels = ['L', 'M', "H"])

# %%
df_new.tail()
# Out:
#      Rank                         Name         City State Public/Private  \
# 623   645            Morehouse College      Atlanta    GA        Private
# 624   646  New Mexico State University   Las Cruces    NM         Public
# 625   647     Indiana State University  Terre Haute    IN         Public
# 626   648    Emory &amp; Henry College        Emory    VA        Private
# 627   650              Catawba College    Salisbury    NC        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 623                      2202                2219    34928.0
# 624                     13379               14432     8625.0
# 625                     13626               13763    13012.0
# 626                      1094                1226    19340.0
# 627                      1336                1463    19807.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 623            17318.0              48723        98700.0             74.0
# ...

# %%
df_new['Alumni Sal Level'].value_counts()
# Out:
# L    383
# M    217
# H     28
# Name: Alumni Sal Level, dtype: int64

# %%
round(df_new.groupby('Alumni Sal Level')['Alumni Salary'].mean(),2)
# Out:
# Alumni Sal Level
# L     89835.77
# M    109086.64
# H    137575.00
# Name: Alumni Salary, dtype: float64

# %%
df_high_sal = df_new[df_new['Alumni Sal Level']=='H']

# %%
df_high_sal.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df_high_sal.describe().T
# Out:
#                           count           mean           std        min  \
# Rank                       28.0      68.857143     87.500144       1.00
# Undergraduate Population   28.0    6389.535714   6290.912467     847.00
# Student Population         28.0   10603.321429  10225.926422     861.00
# Net Price                  28.0   25288.571429   9526.081595    6758.00
# Average Grant Aid          28.0   32340.535714  14681.882361    3597.00
# Total Annual Cost          28.0   62952.464286  14203.545967    8646.00
# Alumni Salary              28.0  137575.000000   7667.566372  129500.00
# Acceptance Rate            28.0      28.035714     21.489846       5.00
# Percentage_UG              28.0      68.703929     19.094700      40.82
#
#                                 25%         50%          75%       max
# Rank                           8.75      41.500      93.2500     333.0
# Undergraduate Population    2759.00    4752.000    7001.7500   31133.0
# ...
